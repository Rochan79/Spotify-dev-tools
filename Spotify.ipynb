# %% [markdown]
# # Learning to use the Spotify API
#
# I am using API token instead of their in-house library Spotipy, as I was having some issues with the OAuth of the same.
#
#
# This notebook can help you to search queries for tracks, artist and albums.
# YOu can get a client ID and client secret by going to SPotify's developer dashboard and creating a new WebApp.

# %%
import requests
import datetime
from urllib.parse import urlencode

# %%
import base64
client_id = '' #put your client_id here
client_secret = '' #put your client_secret here

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret

    def get_client_credentials(self):
        """
        Returns a base64 encoded string
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_secret == None or client_id == None:
            raise Exception("You must set client_id and client_secret")
        client_creds = f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
    
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        } 
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200, 299):
            raise Exception("Could not authenticate client.")
            # return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in'] # seconds
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token() 
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
        
        
    def get_resource(self, lookup_id, resource_type='albums', version='v1'):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def base_search(self, query_params): # type
        headers = self.get_resource_header()
        endpoint = "https://api.spotify.com/v1/search"
        lookup_url = f"{endpoint}?{query_params}"
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):  
            return {}
        return r.json()
    
    def search(self, query=None, operator=None, operator_query=None, search_type='artist' ):
        if query == None:
            raise Exception("A query is required")
        if isinstance(query, dict):
            query = " ".join([f"{k}:{v}" for k,v in query.items()])
        if operator != None and operator_query != None:
            if operator.lower() == "or" or operator.lower() == "not":
                operator = operator.upper()
                if isinstance(operator_query, str):
                    query = f"{query} {operator} {operator_query}"
        query_params = urlencode({"q": query, "type": search_type.lower()})
        print(query_params)
        return self.base_search(query_params)

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
query_response = spotify.search({"track": "Time"}, search_type="track")
# Out:
# q=track%3ATime&type=track

# %%
import pandas as pd    

df = pd.json_normalize(query_response)

# %%
df
# Out:
#                                          tracks.href  \
# 0  https://api.spotify.com/v1/search?query=track%...
#
#                                         tracks.items  tracks.limit  \
# 0  [{'album': {'album_type': 'single', 'artists':...            20
#
#                                          tracks.next  tracks.offset  \
# 0  https://api.spotify.com/v1/search?query=track%...              0
#
#   tracks.previous  tracks.total
# 0            None         10000

# %%
track_item_df =  pd.json_normalize(df['tracks.items'][0])

# %%
track_item_df
# Out:
#                                               artists  \
# 0   [{'external_urls': {'spotify': 'https://open.s...
# 1   [{'external_urls': {'spotify': 'https://open.s...
# 2   [{'external_urls': {'spotify': 'https://open.s...
# 3   [{'external_urls': {'spotify': 'https://open.s...
# 4   [{'external_urls': {'spotify': 'https://open.s...
# 5   [{'external_urls': {'spotify': 'https://open.s...
# 6   [{'external_urls': {'spotify': 'https://open.s...
# 7   [{'external_urls': {'spotify': 'https://open.s...
# 8   [{'external_urls': {'spotify': 'https://open.s...
# 9   [{'external_urls': {'spotify': 'https://open.s...
# 10  [{'external_urls': {'spotify': 'https://open.s...
# 11  [{'external_urls': {'spotify': 'https://open.s...
# 12  [{'external_urls': {'spotify': 'https://open.s...
# 13  [{'external_urls': {'spotify': 'https://open.s...
# 14  [{'external_urls': {'spotify': 'https://open.s...
# 15  [{'external_urls': {'spotify': 'https://open.s...
# 16  [{'external_urls': {'spotify': 'https://open.s...
# 17  [{'external_urls': {'spotify': 'https://open.s...
# 18  [{'external_urls': {'spotify': 'https://open.s...
# 19  [{'external_urls': {'spotify': 'https://open.s...
#
#                                     available_markets  disc_number  \
# 0   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 1   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 2   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 3   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 4   [AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, BR, C...            1
# 5   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 6   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 7   [AD, AE, AG, AM, AO, AR, AT, AU, AZ, BB, BD, B...            1
# 8   [AD, AE, AR, AT, AU, BA, BD, BE, BG, BN, BO, B...            1
# 9   [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 10  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 11  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 12  [AD, AG, AL, AM, AO, AR, AT, AU, AZ, BA, BB, B...            1
# 13  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 14  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 15  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 16  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 17  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 18  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
# 19  [AD, AE, AG, AL, AM, AO, AR, AT, AU, AZ, BA, B...            1
#
#     duration_ms  explicit                                               href  \
# 0        206864     False  https://api.spotify.com/v1/tracks/6KGtAlYvgm4W...
# 1        182306     False  https://api.spotify.com/v1/tracks/2R4AlwtrrkMa...
# 2        151933     False  https://api.spotify.com/v1/tracks/5hslUAKq9I9C...
# 3        191822      True  https://api.spotify.com/v1/tracks/1PckUlxKqWQs...
# 4        214190     False  https://api.spotify.com/v1/tracks/44qEAOL7eiNJ...
# 5        168920      True  https://api.spotify.com/v1/tracks/0YFqKxV9uNu6...
# 6        214193     False  https://api.spotify.com/v1/tracks/2SLwbpExuoBD...
# 7        156081      True  https://api.spotify.com/v1/tracks/240audWazVjw...
# 8        163093     False  https://api.spotify.com/v1/tracks/3bMfUUpzUzqW...
# 9        340706     False  https://api.spotify.com/v1/tracks/5Ohxk2dO5COH...
# 10       229360      True  https://api.spotify.com/v1/tracks/2bJvI42r8EF3...
# 11       202192      True  https://api.spotify.com/v1/tracks/0Oqc0kKFsQ6M...
# 12       197266     False  https://api.spotify.com/v1/tracks/7xoUc6faLbCq...
# 13       211773      True  https://api.spotify.com/v1/tracks/4IO2X2YoXoUM...
# 14       281613     False  https://api.spotify.com/v1/tracks/3gdewACMIVME...
# 15       234800     False  https://api.spotify.com/v1/tracks/0UV5zxRMz6AO...
# 16       191937      True  https://api.spotify.com/v1/tracks/6HMtHNpW6YPi...
# 17       173306     False  https://api.spotify.com/v1/tracks/5WtfUKzXircv...
# 18        98413      True  https://api.spotify.com/v1/tracks/2WxUIiq06XXP...
# 19       192931      True  https://api.spotify.com/v1/tracks/5H4mXWKcicuL...
#
#                         id  is_local  \
# 0   6KGtAlYvgm4W9PoYabFAYE     False
# 1   2R4AlwtrrkMaRKojcTIzmL     False
# 2   5hslUAKq9I9CG2bAulFkHN     False
# 3   1PckUlxKqWQs3RlWXVBLw3     False
# 4   44qEAOL7eiNJplZI5B9rND     False
# 5   0YFqKxV9uNu6LUeYkLOKRS     False
# 6   2SLwbpExuoBDZBpjfefCtV     False
# 7   240audWazVjwvwh7XwfSZE     False
# 8   3bMfUUpzUzqWp9II00yRhE     False
# 9   5Ohxk2dO5COHF1krpoPigN     False
# 10  2bJvI42r8EF3wxjOuDav4r     False
# 11  0Oqc0kKFsQ6MhFOLBNZIGX     False
# 12  7xoUc6faLbCqZO6fQEYprd     False
# 13  4IO2X2YoXoUMv0M2rwomLC     False
# 14  3gdewACMIVMEWVbyb8O9sY     False
# 15  0UV5zxRMz6AO4ZwUOZNIKI     False
# 16  6HMtHNpW6YPi1hrw9tgF8P     False
# 17  5WtfUKzXircvW8l5aaVZWT     False
# 18  2WxUIiq06XXPYWl9YcRJnD     False
# 19  5H4mXWKcicuLKDn4Jy0sK7     False
#
#                                                  name  popularity  ...  \
# 0                                 One Thing At A Time          81  ...
# 1                                  For the First Time          83  ...
# 2            It's the Most Wonderful Time of the Year          87  ...
# 3                                     About Damn Time          86  ...
# 4                                         Out of Time           3  ...
# 5                          On Time (with John Legend)          81  ...
# 6                                         Out of Time          83  ...
# 7                                   For the Last Time          76  ...
# 8                              Christmas Time Is Here          76  ...
# 9                                   Sign of the Times          84  ...
# 10                                  Time of Our Lives          81  ...
# 11                                         Doin' Time          83  ...
# 12                                      One Last Time          83  ...
# 13                                  Long Time - Intro          75  ...
# 14  Rocket Man (I Think It's Going To Be A Long, L...          82  ...
# 15                           Where'd All the Time Go?          77  ...
# 16                                    About Damn Time          80  ...
# 17                    What A Time (feat. Niall Horan)          82  ...
# 18                                           Our Time          78  ...
# 19                                         Time Flies          76  ...
#
#                   album.id                                       album.images  \
# 0   04VpyPCr9PQRWRRp1ecOs1  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1   4NNq2vwTapv4fSJcrZbPH7  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2   4dcJHxlOJwtyypL7sx1qch  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3   4JApkbiesQxv5drdEZRlZC  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4   27Rz5rm7oJke4AQ8LLPexT  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 5   7txGsnDSqVMoRl6RQ9XyZP  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 6   2nLOHgzXzwFEpl62zAgCEC  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 7   4CcyRnFW6Vgf372ca3xFGR  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 8   1d3w7T3iyK3JJQ6kdpE6l9  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 9   1FZKIm3JVDCxTchXDo5jOV  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 10  4EUf4YyNjuXypWY6W5wEDm  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 11  5XpEKORZ4y6OrCZSKsi46A  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 12  6EVYTRG1drKdO8OnIQBeEj  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 13  7dAm8ShwJLFm9SaJ6Yc58O  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 14  2ei2X6ghPnw7YRwQtAH075  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 15  16XswZ18xhMs8qUTN51mRl  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 16  1NgFBv1PxMG1zhFDW1OrRr  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 17  1xJ7jIK1tT0aVoJw1fPE6r  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 18  389zGArsMlwuPorS4Cw7IX  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 19  6OQ9gBfg5EXeNAEwGSs6jK  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                            album.name album.release_date  \
# 0       One Thing At A Time (Sampler)         2022-12-02
# 1                        This Old Dog         2017-05-05
# 2   The Andy Williams Christmas Album         1963-11-24
# 3                     About Damn Time         2022-04-14
# 4             Synchronized Heartbeats         2023-01-20
# 5                   HEROES & VILLAINS         2022-12-02
# 6                             Dawn FM         2022-01-06
# 7                   For the Last Time         2017-09-05
# 8          Charlie Brown Holiday Hits         1998-01-01
# 9                        Harry Styles         2017-05-12
# 10                      Globalization         2014-11-21
# 11           Norman Fucking Rockwell!         2019-08-30
# 12             My Everything (Deluxe)         2014-08-25
# 13                            Die Lit         2018-05-11
# 14                      Honky Chateau         1972-05-19
# 15      Shame, Shame (Deluxe Edition)         2010-11-02
# 16                            Special         2022-07-15
# 17             Inner Monologue Part 1         2019-01-24
# 18                        Virgo World         2020-09-18
# 19               Dark Lane Demo Tapes         2020-05-01
#
#    album.release_date_precision album.total_tracks album.type  \
# 0                           day                  3      album
# 1                           day                 13      album
# 2                           day                 12      album
# 3                           day                  1      album
# 4                           day                 19      album
# 5                           day                 15      album
# 6                           day                 16      album
# 7                           day                  1      album
# 8                           day                 14      album
# 9                           day                 10      album
# 10                          day                 11      album
# 11                          day                 14      album
# 12                          day                 15      album
# 13                          day                 19      album
# 14                          day                 11      album
# 15                          day                 18      album
# 16                          day                 12      album
# 17                          day                  6      album
# 18                          day                 19      album
# 19                          day                 14      album
#
#                                album.uri external_ids.isrc  \
# 0   spotify:album:04VpyPCr9PQRWRRp1ecOs1      USUG12209213
# 1   spotify:album:4NNq2vwTapv4fSJcrZbPH7      QMMZN1701301
# 2   spotify:album:4dcJHxlOJwtyypL7sx1qch      USSM16300086
# 3   spotify:album:4JApkbiesQxv5drdEZRlZC      USAT22202139
# 4   spotify:album:27Rz5rm7oJke4AQ8LLPexT      USUG12106689
# 5   spotify:album:7txGsnDSqVMoRl6RQ9XyZP      USUG12208782
# 6   spotify:album:2nLOHgzXzwFEpl62zAgCEC      USUG12106689
# 7   spotify:album:4CcyRnFW6Vgf372ca3xFGR      QM8DG1703420
# 8   spotify:album:1d3w7T3iyK3JJQ6kdpE6l9      USFI86600065
# 9   spotify:album:1FZKIm3JVDCxTchXDo5jOV      USSM11703595
# 10  spotify:album:4EUf4YyNjuXypWY6W5wEDm      USRC11402647
# 11  spotify:album:5XpEKORZ4y6OrCZSKsi46A      GBUM71903894
# 12  spotify:album:6EVYTRG1drKdO8OnIQBeEj      USUM71409723
# 13  spotify:album:7dAm8ShwJLFm9SaJ6Yc58O      USUM71804186
# 14  spotify:album:2ei2X6ghPnw7YRwQtAH075      GBAMB7200006
# 15  spotify:album:16XswZ18xhMs8qUTN51mRl      USEP40937005
# 16  spotify:album:1NgFBv1PxMG1zhFDW1OrRr      USAT22203704
# 17  spotify:album:1xJ7jIK1tT0aVoJw1fPE6r      USUM71900686
# 18  spotify:album:389zGArsMlwuPorS4Cw7IX      USUM72017151
# 19  spotify:album:6OQ9gBfg5EXeNAEwGSs6jK      USUG12001728
#
#                                 external_urls.spotify
# 0   https://open.spotify.com/track/6KGtAlYvgm4W9Po...
# 1   https://open.spotify.com/track/2R4AlwtrrkMaRKo...
# 2   https://open.spotify.com/track/5hslUAKq9I9CG2b...
# 3   https://open.spotify.com/track/1PckUlxKqWQs3Rl...
# 4   https://open.spotify.com/track/44qEAOL7eiNJplZ...
# 5   https://open.spotify.com/track/0YFqKxV9uNu6LUe...
# 6   https://open.spotify.com/track/2SLwbpExuoBDZBp...
# 7   https://open.spotify.com/track/240audWazVjwvwh...
# 8   https://open.spotify.com/track/3bMfUUpzUzqWp9I...
# 9   https://open.spotify.com/track/5Ohxk2dO5COHF1k...
# 10  https://open.spotify.com/track/2bJvI42r8EF3wxj...
# 11  https://open.spotify.com/track/0Oqc0kKFsQ6MhFO...
# 12  https://open.spotify.com/track/7xoUc6faLbCqZO6...
# 13  https://open.spotify.com/track/4IO2X2YoXoUMv0M...
# 14  https://open.spotify.com/track/3gdewACMIVMEWVb...
# 15  https://open.spotify.com/track/0UV5zxRMz6AO4Zw...
# 16  https://open.spotify.com/track/6HMtHNpW6YPi1hr...
# 17  https://open.spotify.com/track/5WtfUKzXircvW8l...
# 18  https://open.spotify.com/track/2WxUIiq06XXPYWl...
# 19  https://open.spotify.com/track/5H4mXWKcicuLKDn...
#
# [20 rows x 29 columns]
